# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
run multifit.py
# Out:
# [[Variables]]
#     amp_1:   0.50000000 (init= 0.5)
#     cen_1:   0.40000000 (init= 0.4)
#     sig_1:   0.30000000 (init= 0.3)
#     amp_2:   0.50000000 (init= 0.5)
#     cen_2:   0.40000000 (init= 0.4)
#     sig_2:   0.30000000  == 'sig_1'
#     amp_3:   0.50000000 (init= 0.5)
#     cen_3:   0.40000000 (init= 0.4)
#     sig_3:   0.30000000  == 'sig_1'
#     amp_4:   0.50000000 (init= 0.5)
#     cen_4:   0.40000000 (init= 0.4)
#     sig_4:   0.30000000  == 'sig_1'
#     amp_5:   0.50000000 (init= 0.5)
#     cen_5:   0.40000000 (init= 0.4)
#     sig_5:   0.30000000  == 'sig_1'
# [[Correlations]] (unreported correlations are <  0.100)

# %%
dir()
# Out:
# ['In',
#  'Out',
#  'Parameters',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__nonzero__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'amp',
#  'cen',
#  'dat',
#  'data',
#  'exit',
#  'fit_params',
#  'gauss',
#  'gauss_dataset',
#  'get_ipython',
#  'i',
#  'iy',
#  'minimize',
#  'np',
#  'objective',
#  'params',
#  'plt',
#  'quit',
#  'report_fit',
#  'sig',
#  'x',
#  'y',
#  'y_fit']

# %%
data
# Out:
# array([[ -6.61373024e-02,   1.50452147e-01,  -1.44406753e-01,
#          -9.46743806e-02,   6.49392992e-02,   1.68426164e-01,
#          -1.24379752e-01,   3.74884562e-02,   2.77410384e-01,
#           1.88790502e-01,   5.22940770e-02,   1.48120797e-01,
#           1.51832814e-01,   2.05220368e-01,   1.15705455e-01,
#           3.88941044e-01,   2.31159286e-01,   3.24117353e-01,
#           3.40584746e-01,   3.61787966e-01,   3.82050287e-01,
#           6.63612568e-01,   8.15592696e-01,   9.27496733e-01,
#           8.46413955e-01,   1.11659153e+00,   1.32944517e+00,
#           1.65592691e+00,   1.63417821e+00,   2.08061926e+00,
#           2.28670200e+00,   2.61443600e+00,   2.83050892e+00,
#           3.29787307e+00,   3.60866120e+00,   3.93021064e+00,
#           4.40995327e+00,   4.85071382e+00,   5.09046712e+00,
#           5.41229093e+00,   5.88254681e+00,   6.23163166e+00,
#           6.51224786e+00,   7.04800685e+00,   7.33032934e+00,
# ...

# %%
minimize(objective, fit_params, args=(x,data))
