# %%
import numpy as np
import matplotlib.pyplot as plt
import coolmods.models as models
import coolmods.ligtools as ligtools
import coolmods.plotter as plotter
import coolmods.prep as prep
import corner
from scipy import optimize
# %matplotlib inline
# %load_ext autoreload

# %%
ligs = np.array([ligtools.dilser() for i in range(5)])

# %%
rtot = np.array([0.001,0.0025,0.005,0.01,0.025,0.05])

# %%
parm = np.array([3.,2.,0.1,100.])

# %%
datset = np.array([models.wyman_bestfit(parm,ligs[i],rtot[i]) for i in range(len(ligs))])

# %%
plotter.semlog(ligs,datset)

# %%
datsetn = np.random.normal(datset,(0.05*datset))

# %%
plotter.semlog(ligs,datsetn)

# %%
datset_randreps = np.array([np.random.normal(datset,(0.05*datset)) for i in range(3)])

# %%
datset_repavg = datset_randreps.mean(axis=0)

# %%
datset_repsd = datset_randreps.std(axis=0)

# %%
plotter.semlogerr(ligs,datset_repavg,datset_repsd)

# %%
noisedset = [np.array([np.random.normal(datset,(0.05*datset)) for i in range(3)]) for i in range(10)]

# %%
meanset_list = [noisedset[i].mean(axis=0) for i in range(len(superset))]

# %%
stdset_list = [noisedset[i].std(axis=0) for i in range(len(superset))]

# %%
a = plotter.semlogerr(ligs,meanset_list[2],stdset_list[2]) #test one of the sets

# %%
plt.rcParams.update({'font.size': 6})
plt.subplot(221)
plotter.semlogerr(ligs,meanset_list[0],stdset_list[0])
plt.subplot(222)
plotter.semlogerr(ligs,meanset_list[1],stdset_list[1])
plt.subplot(223)
plotter.semlogerr(ligs,meanset_list[2],stdset_list[2])
plt.subplot(224)
plotter.semlogerr(ligs,meanset_list[3],stdset_list[3])

# %%
fig = plt.figure(figsize=(6,2))
sub1 = fig.add_subplot(121)
plotter.semlogerr(ligs,meanset_list[0],stdset_list[0])
sub2 = fig.add_subplot(122, sharey=sub1)
plt.setp(sub2.get_yticklabels(), visible=False)
plotter.semlogerr(ligs,meanset_list[1],stdset_list[1])

# %%
fig, ax = plt.subplots()
ax.errorbar([1,2,3],[1,2,4],[2,3,3])
# Out:
# <Container object of 3 artists>

# %%
sub1 = plt.subplot(121)
plotter.semlogerr(ligs,meanset_list[0],stdset_list[0])
sub2 = plt.subplot(122, sharey=sub1)
plt.setp(sub2.get_yticklabels(), visible=False)
plotter.semlogerr(ligs,meanset_list[1],stdset_list[1])
