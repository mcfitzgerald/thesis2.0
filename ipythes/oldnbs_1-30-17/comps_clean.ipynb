# %%
import numpy as np

# %%
def dilser(low=0.001, limit=100.0, dilfactor = 2.0):
    """Returns a list containing a dilution series that ranges from
    "low" to "limit" by "dilfactor".
    """
    a = [low]
    while a[-1] <= limit:
        a.append(a[len(a)-1]*dilfactor)
    
    return np.array(a)

# %%
lig = dilser()

a = np.delete(lig,[15,16])

b = np.delete(lig,[14,17])

c = np.delete(lig,[13,15])

ligset = np.array([lig,a,lig,b,c])

# %%
rtots = np.array([0.001,0.005, 0.01, 0.02, 0.05])

sim_parms = dict({'k11':3.7, 'k21':1.8, 'k22':0.12, 'l20':293.0})

parmvec = [3.7,1.8,0.12,293.0]

# %%
def wyman_sim_parmvec(parm,lig,rtot):
    """ Generates bound fraction for Wyman model given parameters and returns as 
    nested array simulated dataset  
    parm is a 1-D numpy array that must describe [k11,k21,k22,l20]
    lig is a 1-D array or 1-D array of 1-D arrays of ligand concentrations
    rtot is a 1-D numpy array of total receptor concentrations for each data set
    size of rtot and lig must match 
    """
    k11 = parm[0]
    k21 = parm[1]
    k22 = parm[2]
    l20 = parm[3]
    
    holder = []
    
    for i in range(lig.size):
        rfree = (((-1 - k11*lig[i]) + \
        (np.sqrt((1 + k11*lig[i])**2 + 8*l20*rtot[i]*(1 + k21*lig[i] + \
        k21*k22*(lig[i]**2)))))/(4*l20*(1 + k21*lig[i] + k21*k22*(lig[i]**2))))
        
        bfrac = (k11*lig[i] + l20*k21*rfree*lig[i] + \
        2*l20*k21*k22*rfree*(lig[i]**2))/(1 + 2*l20*rfree + k11*lig[i] + \
        2*l20*k21*rfree*lig[i] + 2*l20*k21*k22*rfree*(lig[i]**2))
        
        holder.append(bfrac)
        
    return np.array(holder)

# %%
bindset = wyman_sim_parmvec(parmvec,ligset,rtots)

# %%
#explicit noise array -- so I can recreate
#note it is set to 3% -- because I am simulating a limited number of data sets
np.random.seed(1776)
noiseset = np.array([np.random.normal(1.0,0.05,bindset[i].size) for i in range(bindset.size)])

# %%
bindset_n = noiseset*bindset

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
clr = ['b','g','r','c','m']

# %%
for i in range(bindset_n.size):
    plt.semilogx(ligset[i],bindset_n[i],'.',color=clr[i])
    plt.semilogx(ligset[i],bindset[i],color=clr[i])

# %%
#define an objective function for use with lmfit (must mesh with lmfit.Parameter class)
def wyman_obj_lmfit(parm,lig,data,rtot,eps=None):
    """maximizes vector ops"""
    k11 = parm['k11']
    k21 = parm['k21']
    k22 = parm['k22']
    l20 = parm['l20']
    
    ligc = np.concatenate(lig)
    datac = np.concatenate(data)
    
    rfree = (((-1 - k11*ligc)) + \
    (np.sqrt(np.concatenate((np.square((1 + k11*lig)) + \
    8.*l20*rtot*(1 + k21*lig + k21*k22*(np.square(lig)))))))) \
    / (4*l20*(1 + k21*ligc + k21*k22*(np.square(ligc))))    
       
    bfrac = (k11*ligc + l20*k21*rfree*ligc + \
    2*l20*k21*k22*rfree*(np.square(ligc))) \
    / (1 + 2*l20*rfree + k11*ligc + \
    2*l20*k21*rfree*ligc + 2*l20*k21*k22*rfree*(np.square(ligc)))
    
    residual = (bfrac - datac)
    
    if eps is None:
        return residual
    else:
        weights = 1/np.square(np.concatenate(eps))
        return (residual*weights)

# %%
#define an objective function for use with lmfit (must mesh with lmfit.Parameter class)
def wyman_obj_lmfit_mod1(parm,lig,data,rtot,eps=None):
    """maximizes vector ops"""
    k11 = parm['k11']
    k21 = parm['k21']
    k22 = parm['k22']
    l20 = parm['l20']
    
    ligc = np.concatenate(lig)
    datac = np.concatenate(data)
    
    rfree = (((-1 - k11*ligc)) + \
    (np.sqrt(np.concatenate((np.square((1 + k11*lig)) + \
    8.*l20*rtot*(1 + k21*lig + k21*k22*(np.square(lig)))))))) \
    / (4*l20*(1 + k21*ligc + k21*k22*(np.square(ligc))))    
       
    bfrac = (k11*ligc + l20*k21*rfree*ligc + \
    2*l20*k21*k22*rfree*(np.square(ligc))) \
    / (1 + 2*l20*rfree + k11*ligc + \
    2*l20*k21*rfree*ligc + 2*l20*k21*k22*rfree*(np.square(ligc)))
    
    residual = (bfrac - datac)
    
    if eps is None:
        return residual
    else:
        weights = 1/np.concatenate(eps)
        return (residual*weights)

# %%
import lmfit

# %%
parms = lmfit.Parameters()

# %%
parms.add('k11', value=10., min=0., max=100.)
parms.add('k21', value=10., min=0., max=100.)
parms.add('k22', value=10., min=0., max=100.)
parms.add('l20', value=100., min=0., max=1000.)

# %%
lmfit_min = lmfit.Minimizer(wyman_obj_lmfit,parms,fcn_args=(ligset,bindset_n,rtots))

# %%
lmfit_res = lmfit_min.minimize(method='least_squares')

# %%
lmfit.report_fit(lmfit_res)
# Out:
# [[Fit Statistics]]
#     # function evals   = 21
#     # data points      = 84
#     # variables        = 4
#     chi-square         = 0.023
#     reduced chi-square = 0.000
#     Akaike info crit   = -679.361
#     Bayesian info crit = -669.638
# [[Variables]]
#     k11:   4.53369549 (init= 10)
#     k21:   2.30981701 (init= 10)
#     k22:   0.29630900 (init= 10)
#     l20:   971.757224 (init= 100)
# [[Correlations]] (unreported correlations are <  0.100)

# %%
bindset_fit = wyman_sim_parmvec(lmfit_res.x,ligset,rtots)

# %%
for i in range(bindset_n.size):
    plt.semilogx(ligset[i],bindset_n[i],'o',color=clr[i])
    plt.semilogx(ligset[i],bindset_fit[i],'--',color=clr[i])
    plt.semilogx(ligset[i],bindset[i],color=clr[i])

# %%
err = 0.05*bindset_n

# %%
lmfit_min_wts = lmfit.Minimizer(wyman_obj_lmfit_mod1,parms,fcn_args=(ligset,bindset_n,rtots,err))

# %%
lmfit_res_wts = lmfit_min_wts.minimize()

# %%
lmfit.report_fit(lmfit_res_wts)
# Out:
# [[Fit Statistics]]
#     # function evals   = 56
#     # data points      = 84
#     # variables        = 4
#     chi-square         = 48.835
#     reduced chi-square = 0.610
#     Akaike info crit   = -37.558
#     Bayesian info crit = -27.835
# [[Variables]]
#     k11:   3.70295553 +/- 0.199285 (5.38%) (init= 10)
#     k21:   1.88618332 +/- 0.084803 (4.50%) (init= 10)
#     k22:   0.18859577 +/- 0.058994 (31.28%) (init= 10)
#     l20:   347.808209 +/- 91.82645 (26.40%) (init= 100)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(k11, l20)                  =  0.965
#     C(k21, l20)                  =  0.823
#     C(k11, k21)                  =  0.683
#     C(k22, l20)                  =  0.647
#     C(k21, k22)                  =  0.570
#     C(k11, k22)                  =  0.563

# %%
sim_parms
# Out:
# {'k11': 3.7, 'k21': 1.8, 'k22': 0.12, 'l20': 293.0}

# %%
parmsols = np.array([10.,10.,1.,100.])

# %%
#define an objective function for use with scipy optimize (obviates parameter class)
#eps is standard deviation
def wyman_obj_vecmin(parm,lig,data,rtot,eps=None):
    k11 = parm[0]
    k21 = parm[1]
    k22 = parm[2]
    l20 = parm[3]
    
    ligc = np.concatenate(lig)
    datac = np.concatenate(data)
    
    rfree = (((-1 - k11*ligc)) + \
    (np.sqrt(np.concatenate((np.square((1 + k11*lig)) + \
    8.*l20*rtot*(1 + k21*lig + k21*k22*(np.square(lig)))))))) \
    / (4*l20*(1 + k21*ligc + k21*k22*(np.square(ligc))))    
       
    bfrac = (k11*ligc + l20*k21*rfree*ligc + \
    2*l20*k21*k22*rfree*(np.square(ligc))) \
    / (1 + 2*l20*rfree + k11*ligc + \
    2*l20*k21*rfree*ligc + 2*l20*k21*k22*rfree*(np.square(ligc)))
    
    residual = (bfrac - datac)

    if eps is None:
        return residual
    else:
        weights = 1/np.square(np.concatenate(eps))
        return (residual*weights)

# %%
#define an objective function for use with scipy optimize (obviates parameter class)
#eps is standard deviation
def wyman_obj_vecmin_mod1(parm,lig,data,rtot,eps=None):
    k11 = parm[0]
    k21 = parm[1]
    k22 = parm[2]
    l20 = parm[3]
    
    ligc = np.concatenate(lig)
    datac = np.concatenate(data)
    
    rfree = (((-1 - k11*ligc)) + \
    (np.sqrt(np.concatenate((np.square((1 + k11*lig)) + \
    8.*l20*rtot*(1 + k21*lig + k21*k22*(np.square(lig)))))))) \
    / (4*l20*(1 + k21*ligc + k21*k22*(np.square(ligc))))    
       
    bfrac = (k11*ligc + l20*k21*rfree*ligc + \
    2*l20*k21*k22*rfree*(np.square(ligc))) \
    / (1 + 2*l20*rfree + k11*ligc + \
    2*l20*k21*rfree*ligc + 2*l20*k21*k22*rfree*(np.square(ligc)))
    
    residual = (bfrac - datac)

    if eps is None:
        return residual
    else:
        weights = 1/(np.concatenate(eps))
        return (residual*weights)

# %%
from scipy import optimize

# %%
bounds=((0.,0.,0.,0.),(100.,100.,100.,1000.))

# %%
res_lsq_bounds = optimize.least_squares(wyman_obj_vecmin_mod1,parmsols,bounds=bounds,args=(ligset,bindset_n,rtots))

# %%
res_lsq_bounds.x
# Out:
# array([  4.53370698e+00,   2.30981862e+00,   2.96309686e-01,
#          9.71766880e+02])

# %%
res_lsq_bounds_wts = optimize.least_squares(wyman_obj_vecmin_mod1,parmsols,bounds=bounds,args=(ligset,bindset_n,rtots,err))

# %%
res_lsq_bounds_wts.x
# Out:
# array([  3.70295915e+00,   1.88618502e+00,   1.88595736e-01,
#          3.47810019e+02])

# %%
bindset_fit_wts = wyman_sim_parmvec(res_lsq_bounds_wts.x,ligset,rtots)

# %%
for i in range(bindset_n.size):
    plt.semilogx(ligset[i],bindset_n[i],'o',color=clr[i])
    plt.semilogx(ligset[i],bindset_fit[i],'--',color=clr[i])
    plt.semilogx(ligset[i],bindset_fit_wts[i],':',color=clr[i])
    plt.semilogx(ligset[i],bindset[i],color=clr[i])
    plt.xlim(0.1,10)

# %%
def lnprob_vec(parm,lig,data,rtot,eps):
    return -0.5 * np.sum((wyman_obj_vecmin_mod1(parm,lig,data,rtot,eps))**2 + np.log(np.concatenate(2 * np.pi * eps**2)))

# %%
def nll(parm,lig,data,rtot,eps):
    return -1*lnprob_vec(parm,lig,data,rtot,eps)

# %%
bnds = ((0,100),(0,100),(0,100),(0,1000))

# %%
optimize.minimize(nll,parmsols,args=(ligset,bindset_n,rtots,err), bounds=bnds)
# Out:
#       fun: -320.49126403068828
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ -1.56319402e-03,  -1.31876732e-03,  -6.48014975e-04,
#          1.70530257e-05])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 220
#       nit: 27
#    status: 0
#   success: True
#         x: array([  3.70289636e+00,   1.88616232e+00,   1.88583737e-01,
#          3.47781068e+02])

# %%
def lnprior(parms,bounds):
    k11,k21,k22,l20 = parms
    k11_lo = bounds[0][0]
    k11_hi = bounds[0][1]
    k21_lo = bounds[1][0]
    k21_hi = bounds[1][1]
    k22_lo = bounds[2][0]
    k22_hi = bounds[2][1]
    l20_lo = bounds[3][0]
    l20_hi = bounds[3][1]
    if k11_lo < k11 < k11_hi and k21_lo < k21 < k22_hi and k22_lo < k22 < k22_hi and l20_lo < l20 < l20_hi:
        return 0.0
    return -np.inf

# %%
outparm = [1.,1.,1.,10000.]

# %%
lnprior(parmvec,bnds)
# Out:
# 0.0

# %%
bnds[0][0]
# Out:
# 0

# %%
sim_parms
# Out:
# {'k11': 3.7, 'k21': 1.8, 'k22': 0.12, 'l20': 293.0}

# %%
def lnprob_jn(parm,lig,data,rtot,eps,bounds):
    lp = lnprior(parm,bounds)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnprob_vec(parm,lig,data,rtot,eps)

# %%
lnprob_jn(parmvec,ligset,bindset_n,rtots,err,bnds)
# Out:
# 318.01150842777258

# %%
lnprob_vec(parmvec,ligset,bindset_n,rtots)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-e85319e345b0> in <module>()
# ----> 1 lnprob_vec(parmvec,ligset,bindset_n,rtots)
#
# TypeError: lnprob_vec() missing 1 required positional argument: 'eps'

# %%
resul = optimize.minimize(nll,parmsols,args=(ligset,bindset_n,rtots,err), bounds=bnds)

# %%
resul["x"]
# Out:
# array([  3.70289636e+00,   1.88616232e+00,   1.88583737e-01,
#          3.47781068e+02])

# %%
resul.x
# Out:
# array([  3.70289636e+00,   1.88616232e+00,   1.88583737e-01,
#          3.47781068e+02])

# %%
ndim, nwalkers = 4, 100

# %%
pos = [resul.x + 1e-4*np.random.randn(ndim) for i in range(nwalkers)]

# %%
pos1 = [resul.x + 1e-2*np.random.randn(ndim) for i in range(nwalkers)]

# %%
import emcee

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob_jn, args=(ligset,bindset_n,rtots,err,bnds))

# %%
sampler.run_mcmc(pos, 1000)
# Out:
# (array([[  3.70106477e+00,   1.80540181e+00,   1.03223070e-01,
#            3.16395018e+02],
#         [  3.97227153e+00,   1.89729487e+00,   1.47024038e-01,
#            4.55087973e+02],
#         [  3.69888496e+00,   1.83571066e+00,   1.82798981e-01,
#            3.19096008e+02],
#         [  3.71159647e+00,   1.86141021e+00,   2.07596363e-01,
#            3.49956296e+02],
#         [  3.69000924e+00,   1.80147536e+00,   1.38206181e-01,
#            3.27858484e+02],
#         [  4.00795094e+00,   2.04184547e+00,   2.42850607e-01,
#            5.50812727e+02],
#         [  3.91685090e+00,   1.83685152e+00,   1.67718309e-01,
#            4.23333619e+02],
#         [  3.76540833e+00,   1.86411783e+00,   3.34254959e-01,
#            3.91628950e+02],
#         [  3.62416175e+00,   1.85365877e+00,   1.82387930e-01,
#            3.10094763e+02],
#         [  4.13533614e+00,   1.88373050e+00,   2.14216950e-01,
#            5.06623982e+02],
#         [  3.61068275e+00,   1.97521479e+00,   3.71329401e-01,
#            3.76901068e+02],
#         [  4.02352689e+00,   2.00510139e+00,   2.87854036e-01,
#            5.77532367e+02],
#         [  4.77212012e+00,   1.96917631e+00,   4.13908134e-01,
#            9.76255608e+02],
#         [  4.53506246e+00,   1.90323050e+00,   2.64873900e-01,
#            7.31400474e+02],
#         [  4.09037767e+00,   1.92043231e+00,   1.53087436e-01,
#            5.18732933e+02],
#         [  3.63913853e+00,   1.87186097e+00,   1.59413867e-01,
#            3.20228033e+02],
#         [  4.56617839e+00,   2.18230092e+00,   3.64845365e-01,
#            9.48188186e+02],
#         [  3.84166505e+00,   1.86389695e+00,   9.69413978e-02,
#            3.89726761e+02],
#         [  4.15276854e+00,   1.98031276e+00,   2.45747538e-01,
#            5.56839763e+02],
#         [  3.63495001e+00,   1.87408176e+00,   2.53071978e-01,
#            3.37849500e+02],
#         [  3.98409572e+00,   1.95501346e+00,   2.27702137e-01,
#            4.60881805e+02],
#         [  4.07794155e+00,   1.91194906e+00,   1.46557776e-01,
#            4.76439337e+02],
#         [  3.97066287e+00,   2.13564133e+00,   2.86088239e-01,
#            5.83436404e+02],
#         [  3.75531941e+00,   1.85315185e+00,   8.53809376e-02,
#            3.36503655e+02],
#         [  3.81632630e+00,   2.03718796e+00,   1.71011971e-01,
#            4.94734969e+02],
#         [  3.86029846e+00,   1.91796912e+00,   2.46046599e-01,
#            4.04882347e+02],
#         [  3.90536177e+00,   1.93266615e+00,   2.94273796e-01,
#            4.51289428e+02],
#         [  4.10754570e+00,   2.10307397e+00,   2.34440853e-01,
#            6.41645266e+02],
#          1091609553, 2163960842, 1421603834, 3887515678, 2637338755,
#          1047522245, 3159616443, 4278853386, 2362637027,  533179199,
#          1804204882, 1223227012, 3694816650, 3331500783,  410822181,
#            32719986,  646098452, 3224283169, 1735576331,   87100594,
#           326638655, 1198264323, 1460518629, 3755246221, 3099262885,
#          1702578652, 2044878561, 1673782290, 1076539701, 3743461720,
#           867438755, 3997344490, 3674551856, 1606495948, 4192330418,
#          2754760686, 2072812272, 1848130504, 2884609149, 3322427986,
#           111682635,  919734662,  781725653,  954194045,  578749668,
#           994605400, 3235288803, 3921878433, 4261883451, 1519574868,
#          2770708712, 3822742462, 2136143588, 3995450507, 2365383007,
#          2725210459,  322178910, 1064859709, 4143501913, 3572264977,
#           772073028, 2733646184, 2459691900,  484175911], dtype=uint32), 372, 0, 0.0))

# %%
plt.plot(sampler.chain[:,:,0].T, '-', color='k', alpha=0.3);

# %%
def lnprob_lmfit(parm,lig,data,rtot,eps):
    return -0.5 * np.sum((wyman_obj_lmfit_mod1(parm,lig,data,rtot,eps))**2 + np.log(np.concatenate(2 * np.pi * eps**2)))

# %%
lnprob_lmfit(parms,ligset,bindset_n,rtots,err)
# Out:
# -71413.080963110391

# %%
lnprob_vec(parmsols,ligset,bindset_n,rtots,err)
# Out:
# -57230.756972024901

# %%
parmsols[2] = 10.

# %%
lnprob_vec(parmsols,ligset,bindset_n,rtots,err)
# Out:
# -71413.080963110391

# %%
lmfit_res_wts.params
# Out:
# Parameters([('k11',
#              <Parameter 'k11', value=3.7029555297315331 +/- 0.199, bounds=[0.0:100.0]>),
#             ('k21',
#              <Parameter 'k21', value=1.8861833215154444 +/- 0.0848, bounds=[0.0:100.0]>),
#             ('k22',
#              <Parameter 'k22', value=0.18859577842798569 +/- 0.059, bounds=[0.0:100.0]>),
#             ('l20',
#              <Parameter 'l20', value=347.80820926833383 +/- 91.8, bounds=[0.0:1000.0]>)])

# %%
mini = lmfit.Minimizer(lnprob_lmfit, lmfit_res_wts.params, fcn_args=(ligset,bindset_n,rtots,err))

# %%
res = mini.emcee()

# %%
plt.plot(res.chain[:,:,3].T, '-', color='k', alpha=0.3);

# %%
import cProfile

# %%
mini1 = lmfit.Minimizer(lnprob_lmfit, lmfit_res_wts.params, fcn_args=(ligset,bindset_n,rtots,err))
cProfile.run('res1=mini1.emcee(steps=2000)')
# Out:
#          34892524 function calls (34892508 primitive calls) in 128.716 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    189901    6.760    0.000  104.072    0.001 <ipython-input-124-bf8e9cd493f0>:1(lnprob_lmfit)
#    189901   49.911    0.000   93.914    0.000 <ipython-input-14-07239b8ac76b>:2(wyman_obj_lmfit_mod1)
#         1    0.000    0.000  128.716  128.716 <string>:1(<module>)
#    379801    0.294    0.000    2.932    0.000 _methods.py:31(_sum)
#    411307    0.250    0.000    2.439    0.000 _methods.py:37(_any)
#         1    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#         1    0.000    0.000    0.004    0.004 _methods.py:53(_mean)
#       390    0.000    0.000    0.000    0.000 asteval.py:104(<genexpr>)
#         9    0.000    0.000    0.000    0.000 asteval.py:108(<genexpr>)
#        41    0.000    0.000    0.000    0.000 asteval.py:113(<genexpr>)
#         1    0.000    0.000    0.000    0.000 asteval.py:120(<listcomp>)
#         1    0.000    0.000    0.000    0.000 asteval.py:124(user_defined_symbols)
#         1    0.000    0.000    0.001    0.001 asteval.py:72(__init__)
#        89    0.000    0.000    0.000    0.000 asteval.py:89(<genexpr>)
#         2    0.000    0.000    0.000    0.000 asteval.py:94(<genexpr>)
#        38    0.000    0.000    0.000    0.000 asteval.py:98(<genexpr>)
#         4    0.000    0.000    0.000    0.000 astutils.py:179(valid_symbol_name)
#      17/1    0.000    0.000    0.002    0.002 copy.py:137(deepcopy)
#        12    0.000    0.000    0.000    0.000 copy.py:192(_deepcopy_atomic)
#         5    0.000    0.000    0.000    0.000 copy.py:253(_keep_alive)
#         1    0.000    0.000    0.000    0.000 ensemble.py:109(clear_blobs)
#         1    0.000    0.000    0.000    0.000 ensemble.py:116(reset)
#      2001    0.235    0.000  128.672    0.064 ensemble.py:130(sample)
#      4000    0.379    0.000  128.268    0.032 ensemble.py:292(_propose_stretch)
#      4001    0.522    0.000  127.795    0.032 ensemble.py:340(_get_lnprob)
#      4001    0.068    0.000    0.068    0.000 ensemble.py:382(<listcomp>)
#      4001    0.069    0.000    0.069    0.000 ensemble.py:385(<listcomp>)
#       364    0.002    0.000    0.002    0.000 ensemble.py:386(<listcomp>)
#      4001    0.071    0.000    0.071    0.000 ensemble.py:388(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ensemble.py:423(chain)
#         1    0.000    0.000    0.000    0.000 ensemble.py:442(lnprobability)
#         1    0.000    0.000    0.000    0.000 ensemble.py:512(__init__)
#    200100    0.462    0.000  126.880    0.001 ensemble.py:517(__call__)
#         1    0.000    0.000    0.005    0.005 ensemble.py:80(__init__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1206(diagonal)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1686(clip)
#    379801    1.454    0.000    5.255    0.000 fromnumeric.py:1743(sum)
#    411307    0.936    0.000    4.344    0.000 fromnumeric.py:1900(any)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:55(take)
#         2    0.000    0.000    0.002    0.001 function_base.py:1264(copy)
#         1    0.003    0.003    0.009    0.009 function_base.py:2298(cov)
#         1    0.001    0.001    0.010    0.010 function_base.py:2500(corrcoef)
#         1    0.001    0.001    0.020    0.020 function_base.py:3369(_ureduce)
#         1    0.000    0.000    0.020    0.020 function_base.py:3588(percentile)
#         1    0.000    0.000    0.019    0.019 function_base.py:3709(_percentile)
#         1    0.000    0.000    0.004    0.004 function_base.py:857(average)
#    200100    5.847    0.000  126.419    0.001 minimizer.py:1269(_lnpost)
#         1    0.000    0.000    0.000    0.000 minimizer.py:1362(_make_random_gen)
#    189900    2.291    0.000    8.877    0.000 minimizer.py:1380(_nan_policy)
#         1    0.000    0.000    0.000    0.000 minimizer.py:212(__init__)
#         1    0.000    0.000    0.002    0.002 minimizer.py:430(prepare_fit)
#         1    0.000    0.000    0.000    0.000 minimizer.py:474(<dictcomp>)
#         1    0.000    0.000  128.716  128.716 minimizer.py:606(emcee)
#         5    0.000    0.000    0.000    0.000 numeric.py:1404(rollaxis)
#    379800    1.141    0.000    2.919    0.000 numeric.py:2576(seterr)
#    379800    1.108    0.000    1.167    0.000 numeric.py:2676(geterr)
#    189900    0.336    0.000    0.400    0.000 numeric.py:2963(__init__)
#    189900    0.306    0.000    1.963    0.000 numeric.py:2967(__enter__)
#    189900    0.408    0.000    1.669    0.000 numeric.py:2972(__exit__)
#    191905    0.260    0.000    0.854    0.000 numeric.py:414(asarray)
#    419311    0.467    0.000    0.578    0.000 numeric.py:484(asanyarray)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:660(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:728(issubdtype)
#         4    0.000    0.000    0.000    0.000 parameter.py:122(__setitem__)
#    189902    1.142    0.000    1.500    0.000 parameter.py:199(update_constraints)
#    189902    0.286    0.000    0.286    0.000 parameter.py:204(<genexpr>)
#         4    0.000    0.000    0.000    0.000 parameter.py:24(isclose)
#         1    0.000    0.000    0.000    0.000 parameter.py:295(add_many)
#         4    0.000    0.000    0.000    0.000 parameter.py:442(__init__)
#         4    0.000    0.000    0.000    0.000 parameter.py:45(within_tol)
#         4    0.000    0.000    0.000    0.000 parameter.py:508(_init_bounds)
#         8    0.000    0.000    0.000    0.000 parameter.py:559(setup_bounds)
#   4367739    8.747    0.000   15.530    0.000 parameter.py:613(_getval)
#        16    0.000    0.000    0.000    0.000 parameter.py:653(value)
#   5127343    5.038    0.000    6.006    0.000 parameter.py:658(value)
#        12    0.000    0.000    0.000    0.000 parameter.py:669(expr)
#         4    0.000    0.000    0.000    0.000 parameter.py:676(expr)
#         4    0.000    0.000    0.000    0.000 parameter.py:684(__set_expression)
#   1519208    2.606    0.000    9.258    0.000 parameter.py:699(__array__)
#         1    0.000    0.000    0.001    0.001 parameter.py:75(__init__)
#   1709109   19.225    0.000   28.926    0.000 parameter.py:760(__mul__)
#   1139406    1.918    0.000    6.138    0.000 parameter.py:813(__rmul__)
#         1    0.000    0.000    0.002    0.002 parameter.py:91(__deepcopy__)
#         1    0.000    0.000    0.000    0.000 parameter.py:99(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 sampler.py:118(reset)
#         1    0.004    0.004  128.676  128.676 sampler.py:135(run_mcmc)
#         1    0.005    0.005    0.005    0.005 sampler.py:37(__init__)
#      2000    0.004    0.000    0.042    0.000 sampler.py:49(random_state)
#         1    0.000    0.000    0.000    0.000 sampler.py:61(random_state)
#         1    0.000    0.000    0.000    0.000 sampler.py:81(chain)
#         1    0.000    0.000    0.000    0.000 sampler.py:97(lnprobability)
#      8000    0.031    0.000    0.049    0.000 shape_base.py:61(atleast_2d)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:244(diag)
#         1    0.000    0.000    0.000    0.000 type_check.py:237(iscomplexobj)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       479    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000  128.716  128.716 {built-in method builtins.exec}
#       479    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#   5127782    0.969    0.000    0.969    0.000 {built-in method builtins.hasattr}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#   4747557    1.979    0.000    1.979    0.000 {built-in method builtins.isinstance}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#     40008    0.008    0.000    0.008    0.000 {built-in method builtins.len}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#   2134796    2.207    0.000    2.207    0.000 {built-in method numpy.core.multiarray.array}
#    949509    3.963    0.000    3.963    0.000 {built-in method numpy.core.multiarray.concatenate}
#         1    0.001    0.001    0.001    0.001 {built-in method numpy.core.multiarray.dot}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.result_type}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#    759600    0.224    0.000    0.224    0.000 {built-in method numpy.core.umath.geterrobj}
#    379800    0.446    0.000    0.446    0.000 {built-in method numpy.core.umath.seterrobj}
#         4    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#    411307    0.403    0.000    2.842    0.000 {method 'any' of 'numpy.ndarray' objects}
#      8020    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.002    0.002    0.002    0.002 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        35    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#      2000    0.025    0.000    0.038    0.000 {method 'get_state' of 'mtrand.RandomState' objects}
#    189904    0.072    0.000    0.072    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.004    0.004 {method 'mean' of 'numpy.ndarray' objects}
#         1    0.017    0.017    0.017    0.017 {method 'partition' of 'numpy.ndarray' objects}
#    189900    0.064    0.000    0.064    0.000 {method 'pop' of 'dict' objects}
#      8000    0.064    0.000    0.064    0.000 {method 'rand' of 'mtrand.RandomState' objects}
#      4000    0.048    0.000    0.048    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'randn' of 'mtrand.RandomState' objects}
#    189901    0.167    0.000    0.167    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    791109    4.831    0.000    4.831    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'set_state' of 'mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#    189900    0.636    0.000    1.938    0.000 {method 'sum' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'collections.OrderedDict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
res1

# %%
sampler1 = emcee.EnsembleSampler(nwalkers, ndim, lnprob_jn, args=(ligset,bindset_n,rtots,err,bnds))
cProfile.run('sampler1.run_mcmc(pos, 2000)')
# Out:
#          2913406 function calls in 50.437 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    190824   34.272    0.000   37.038    0.000 <ipython-input-30-1ff109855aa1>:3(wyman_obj_vecmin_mod1)
#    190824    6.137    0.000   46.039    0.000 <ipython-input-85-d1d972ffee81>:1(lnprob_vec)
#    200100    1.515    0.000    1.515    0.000 <ipython-input-89-c443bcdc9d2f>:1(lnprior)
#    200100    1.062    0.000   48.615    0.000 <ipython-input-94-a1137b75076b>:1(lnprob_jn)
#         1    0.000    0.000   50.437   50.437 <string>:1(<module>)
#    190824    0.131    0.000    1.361    0.000 _methods.py:31(_sum)
#     16004    0.011    0.000    0.111    0.000 _methods.py:37(_any)
#      2001    0.215    0.000   50.434    0.025 ensemble.py:130(sample)
#      4000    0.281    0.000   50.094    0.013 ensemble.py:292(_propose_stretch)
#      4001    0.450    0.000   49.694    0.012 ensemble.py:340(_get_lnprob)
#      4001    0.067    0.000    0.067    0.000 ensemble.py:382(<listcomp>)
#      4001    0.023    0.000    0.023    0.000 ensemble.py:385(<listcomp>)
#      4001    0.061    0.000    0.061    0.000 ensemble.py:388(<listcomp>)
#    200100    0.290    0.000   48.905    0.000 ensemble.py:517(__call__)
#    190824    0.735    0.000    2.217    0.000 fromnumeric.py:1743(sum)
#     16004    0.041    0.000    0.198    0.000 fromnumeric.py:1900(any)
#      2000    0.004    0.000    0.015    0.000 numeric.py:414(asarray)
#     24004    0.031    0.000    0.038    0.000 numeric.py:484(asanyarray)
#         1    0.004    0.004   50.437   50.437 sampler.py:135(run_mcmc)
#      2000    0.003    0.000    0.042    0.000 sampler.py:49(random_state)
#         1    0.000    0.000    0.000    0.000 sampler.py:61(random_state)
#      8000    0.029    0.000    0.046    0.000 shape_base.py:61(atleast_2d)
#         1    0.000    0.000   50.437   50.437 {built-in method builtins.exec}
#    190824    0.121    0.000    0.121    0.000 {built-in method builtins.isinstance}
#     40001    0.007    0.000    0.007    0.000 {built-in method builtins.len}
#     30006    0.054    0.000    0.054    0.000 {built-in method numpy.core.multiarray.array}
#    954122    3.420    0.000    3.420    0.000 {built-in method numpy.core.multiarray.concatenate}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#     16004    0.018    0.000    0.130    0.000 {method 'any' of 'numpy.ndarray' objects}
#      8000    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      2000    0.023    0.000    0.039    0.000 {method 'get_state' of 'mtrand.RandomState' objects}
#      8000    0.057    0.000    0.057    0.000 {method 'rand' of 'mtrand.RandomState' objects}
#      4000    0.041    0.000    0.041    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#    206828    1.331    0.000    1.331    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'set_state' of 'mtrand.RandomState' objects}

# %%
sampler3 = emcee.EnsembleSampler(nwalkers, ndim, lnprob_jn, args=(ligset,bindset_n,rtots,err,bnds))

# %%
sampler3.run_mcmc(pos1,2000);
# Out:
# (array([[  3.69259903e+00,   1.86484952e+00,   2.33980203e-01,
#            3.62319609e+02],
#         [  3.86245267e+00,   1.91404284e+00,   9.68590401e-02,
#            3.96775134e+02],
#         [  3.95829392e+00,   2.08277571e+00,   2.10922399e-01,
#            5.77658067e+02],
#         [  3.98602772e+00,   2.03243881e+00,   2.69267207e-01,
#            5.29121886e+02],
#         [  4.04026976e+00,   2.02119375e+00,   3.15743043e-01,
#            5.32539954e+02],
#         [  3.72269338e+00,   1.97410624e+00,   2.23706131e-01,
#            3.64918157e+02],
#         [  4.41808559e+00,   1.97053923e+00,   1.84331128e-01,
#            6.92463503e+02],
#         [  4.17361493e+00,   1.98363031e+00,   2.66319535e-01,
#            6.36449999e+02],
#         [  3.70860863e+00,   1.96061246e+00,   3.59954422e-01,
#            3.94085823e+02],
#         [  3.65428373e+00,   1.95513760e+00,   2.20182594e-01,
#            3.35873778e+02],
#         [  3.94757894e+00,   1.93326797e+00,   3.45983760e-01,
#            4.87391179e+02],
#          1149784250, 4249578904, 2682803078, 2533662407, 2049747189,
#          2572587769, 1822974520, 2052828621, 3030647983, 2445376379,
#           944414522, 3783746924, 3463180063, 3951208619, 1192771634,
#            94253496,   18557758, 1053250657, 4203952876, 3113551334,
#          3264574507, 2026254568,  867432555, 3687649287,  833450901,
#          3197418832, 3531457276, 2542354442,  948759406, 1524777757,
#          1027796228, 3364724644, 1687852236, 1186283230, 1014752280,
#          3198484528, 3669796021, 2198057792, 3992514909, 3351301257,
#          3241672095, 1897593321, 1874030807,  520702652,  503502344,
#          1002266650,  424253306,  935790624, 1373203861, 4070833320,
#          3851742548, 3782822873, 2053931703,  671099085, 1087799471,
#          2406079843,  777471150, 1584528374, 1543691057, 3247927990,
#          2039847832, 2436369170, 1087200452,  393173087, 2373928650,
#          1094293307, 2234620147, 3128750977, 4151052349, 3541452568,
#          2431396438,  521302667,  996588399,  385217694, 3734402228,
#          2219538953,  201792447,  857921254, 2129657753, 2917673766,
#          1464129024, 1476048412,  582312716, 3886045802, 3528911839,
#          4034880662,  401758527, 4154053702, 4061347992,  871297661,
#          3501482954, 3871118303, 2403307004, 3115211377, 1704394193,
#           229433303,  100178835, 3000908057, 1292824975,   33603663,
#          4123967509, 3500921868, 2791785142, 1988452860, 4178892852,
#          2285403245, 3944498406,  137798664, 3704720322,  398782782,
#          2352263882, 1783502169, 4122189572, 1356912864,  998568393,
#          3812284273, 3963893559,  576327797, 2434234928, 1991968292,
#          3789673956, 3518798337, 2882977884, 2694515504, 2464663027,
#           926849285, 3732371952, 1235984347,  994104848, 4286490082,
#          1289526442, 3510170676, 2393859711, 4271784805, 2848110327,
#          3171932620, 2586815706,  964528044, 3188860569, 1045454538,
#           576896955, 2476949045, 3547699982,  966204353, 2683491085,
#          1301809941,  265113992, 2052719584, 3523697324, 3955310493,
#          1008153402, 1429486413, 1404507584, 2578542593, 1087646395,
#          2584020759, 2257166573, 1750367947, 1147668511,  140417208,
#           996738045, 2768800218, 1049374080, 2326307977, 3583494207,
#          4255613879, 1020787554, 2984977881, 3192820108,   74541982,
#           485570535, 4063640517, 3566474662,   42067824, 2589966679,
#           224309807,  280835390, 1613676673, 1247775563, 2921195578,
#          3315501748,  721199986, 4240142418, 4022289370, 1878240723,
#          3952681845, 1855784890,  974007894, 1121203942,  140902929,
#          1447252992, 1379518255, 1438651501, 1813941551], dtype=uint32), 501, 0, 0.0))

# %%
plt.plot(sampler3.chain[:,:,2].T, '-', color='k', alpha=0.3);

# %%
import corner

# %%
samples = sampler3.chain[:, 50:, :].reshape((-1, ndim))

# %%
corner.corner(samples,labels=['k11','k21','k22','l20'],truths=[3.7,1.8,0.12,293])

# %%
parmvec
# Out:
# [3.7, 1.8, 0.12, 293.0]

# %%
a=corner.corner(res1.flatchain, labels=res1.var_names, truths=list(res1.params.valuesdict().values()))

# %%
plt.plot(res1.chain[:,:,3].T, '-', color='k', alpha=0.3);

# %%
plt.plot(sampler3.chain[:,:,3].T, '-', color='k', alpha=0.3);
