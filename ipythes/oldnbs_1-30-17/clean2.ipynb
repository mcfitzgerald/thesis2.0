# %%
import numpy as np

# %%
def dilser(low=0.001, limit=100.0, dilfactor = 2.0):
    """Returns a list containing a dilution series that ranges from
    "low" to "limit" by "dilfactor".
    """
    a = [low]
    while a[-1] <= limit:
        a.append(a[len(a)-1]*dilfactor)
    
    return np.array(a)

# %%
lig = dilser()

# %%
a = np.delete(lig,[15,16])

# %%
b = np.delete(lig,[14,17])

# %%
c = np.delete(lig,[13,15])

# %%
ligset = np.array([lig,a,lig,b,c])

# %%
noiseset = np.array([np.random.normal(1,0.05,ligset[i].size) for i in range(ligset.shape[0])])

# %%
rtots = np.array([0.001,0.005, 0.01, 0.02, 0.05])

# %%
sim_parms = dict({'k11':3.75, 'k21':1.81, 'k22':0.115, 'l20':283.0})

# %%
def wyman_sim(lig,rtot,parm):
    """
    returns bound fraction for model of aggregating system as described by Wyman and implemened
    by Pike
    
    lig 
    -------
    is an array of arrays (created from a list of arrays -- because
    datasets may not have a uniform number of data points in each experiment)
    
    this is important for the loop below that uses lig.size to generate indices. if lig 
    was a proper array, size would be the total number of cells, but in this case it is the 
    number of arrays (or experimental data sets) in the array
    
    rtot 
    -------
    is a 1d array (but may work as other data structure -- test this)
    
    parm
    -------
    dict of parameter names and values or a Parameters object from the lmfit package
     
    """
    #assign parameter values
    k11 = parm['k11']
    k21 = parm['k21']
    k22 = parm['k22']
    l20 = parm['l20']
    
    holder = []
    
    for i in range(lig.size):
        rfree = (((-1 - k11*lig[i]) + \
        (np.sqrt((1 + k11*lig[i])**2 + 8*l20*rtot[i]*(1 + k21*lig[i] + \
        k21*k22*(lig[i]**2)))))/(4*l20*(1 + k21*lig[i] + k21*k22*(lig[i]**2))))
        
        bfrac = (k11*lig[i] + l20*k21*rfree*lig[i] + \
        2*l20*k21*k22*rfree*(lig[i]**2))/(1 + 2*l20*rfree + k11*lig[i] + \
        2*l20*k21*rfree*lig[i] + 2*l20*k21*k22*rfree*(lig[i]**2))
        
        holder.append(bfrac)
        
    return np.array(holder)

# %%
bindset = wyman_sim(ligset,rtots,sim_parms)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
for i in range(bindset.size):
    plt.semilogx(ligset[i],bindset[i], 'o', label=str(rtots[i]))
    plt.legend()

# %%
bindset_n = bindset*noiseset

# %%
for i in range(bindset_n.size):
    plt.semilogx(ligset[i],bindset_n[i],'o',label=str(rtots[i]))
    plt.legend()

# %%
err = 0.05*bindset_n

# %%
for i in range(bindset_n.size):
    plt.semilogx(ligset[i],noiseset[i],'o',label=str(rtots[i]))
    plt.legend()

# %%
def wym_obj2(parm,lig,rtot,data,eps=None):
    """
    parms
    --------
    lmfit.Parameters() object containin definitions for k11, k21, k22, and l20
    
    x
    --------
    array of arrays (probably assymetric elements without "formal" dimensions) containing 
    free ligand concentrations, must be of same size (no. of elements) as rtots, and same "shape"
    as data (same number of arrays within the array and the same number of elements in each subarray)
    
    Continue documentation
    """
    
    k11 = parm['k11']
    k21 = parm['k21']
    k22 = parm['k22']
    l20 = parm['l20']
    
    model = []
    
    for i in range(lig.size):
        rfree = (((-1 - k11*lig[i]) + \
        (np.sqrt((1 + k11*lig[i])**2 + 8*l20*rtot[i]*(1 + k21*lig[i] + \
        k21*k22*(lig[i]**2)))))/(4*l20*(1 + k21*lig[i] + k21*k22*(lig[i]**2))))
        
        bfrac = (k11*lig[i] + l20*k21*rfree*lig[i] + \
        2*l20*k21*k22*rfree*(lig[i]**2))/(1 + 2*l20*rfree + k11*lig[i] + \
        2*l20*k21*rfree*lig[i] + 2*l20*k21*k22*rfree*(lig[i]**2))
        
        model.append(bfrac)
        
    if eps is None:
        return np.concatenate((np.array(model)) - data)
    else:
        weights = 1/(np.square(eps))
        return np.concatenate(((np.array(model)) - data)*weights)

# %%
import lmfit

# %%
parms = lmfit.Parameters()

# %%
parms.add('k11', value=10., min=0.01)
parms.add('k21', value=10., min=0.01)
parms.add('k22', value=10., min=0.01)
parms.add('l20', value=100., min=0.01)

# %%
wyminner_wts = lmfit.Minimizer(wym_obj2,parms,fcn_args=(ligset,rtots,bindset_n,err))

# %%
result = wyminner_wts.minimize(method='least_squares', loss='soft_l1')

# %%
lmfit.report_fit(result)
# Out:
# [[Fit Statistics]]
#     # function evals   = 401
#     # data points      = 84
#     # variables        = 4
#     chi-square         = 604379632.403
#     reduced chi-square = 7554745.405
#     Akaike info crit   = 1334.267
#     Bayesian info crit = 1343.991
# [[Variables]]
#     k11:   4.00027135 (init= 10)
#     k21:   1.99362308 (init= 10)
#     k22:   0.24052328 (init= 10)
#     l20:   454.176495 (init= 100)
# [[Correlations]] (unreported correlations are <  0.100)

# %%
def lnprob2(parm,x,rtot,data,eps=None):
    return -0.5 * np.sum((wym_obj2(parm,x,rtot,data,eps))**2 + np.log(np.concatenate(2 * np.pi * eps**2)))

# %%
lnprob2(result.params,ligset,rtots,bindset_n,err)
# Out:
# -302189472.47791296

# %%
mcmc = lmfit.Minimizer(lnprob2, result.params, fcn_args=(ligset,rtots,bindset_n,err))

# %%
result_mc = mcmc.emcee(steps=50)

# %%
import corner

# %%
corner.corner(result_mc.flatchain)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
result.params
# Out:
# Parameters([('k11', <Parameter 'k11', 4.0002713533678866, bounds=[0.01:inf]>),
#             ('k21', <Parameter 'k21', 1.9936230842044997, bounds=[0.01:inf]>),
#             ('k22', <Parameter 'k22', 0.2405232844404892, bounds=[0.01:inf]>),
#             ('l20', <Parameter 'l20', 454.17649544551739, bounds=[0.01:inf]>)])

# %%
result_mc.params
# Out:
# Parameters([('k11',
#              <Parameter 'k11', value=3.9999807738180899 +/- 0.0229, bounds=[0.01:inf]>),
#             ('k21',
#              <Parameter 'k21', value=1.988428001901654 +/- 0.0237, bounds=[0.01:inf]>),
#             ('k22',
#              <Parameter 'k22', value=0.24051113702349539 +/- 0.00115, bounds=[0.01:inf]>),
#             ('l20',
#              <Parameter 'l20', value=454.28549412164421 +/- 3.88, bounds=[0.01:inf]>)])

# %%
29
# Out:
# 29

# %%
import cProfile

# %%
cProfile.run('result_mc = mcmc.emcee(steps=50)')
# Out:
#          3461319 function calls (3461303 primitive calls) in 9.740 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      5101    4.335    0.001    8.698    0.002 <ipython-input-54-0d909cedd6b9>:1(wym_obj2)
#      5101    0.226    0.000    9.031    0.002 <ipython-input-61-ec205388ff0e>:1(lnprob2)
#         1    0.000    0.000    9.740    9.740 <string>:1(<module>)
#     10201    0.009    0.000    0.087    0.000 _methods.py:31(_sum)
#     10605    0.007    0.000    0.060    0.000 _methods.py:37(_any)
#         1    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#         1    0.000    0.000    0.000    0.000 _methods.py:53(_mean)
#       390    0.000    0.000    0.001    0.000 asteval.py:104(<genexpr>)
#         9    0.000    0.000    0.000    0.000 asteval.py:108(<genexpr>)
#        41    0.000    0.000    0.000    0.000 asteval.py:113(<genexpr>)
#         1    0.000    0.000    0.000    0.000 asteval.py:120(<listcomp>)
#         1    0.000    0.000    0.000    0.000 asteval.py:124(user_defined_symbols)
#         1    0.000    0.000    0.002    0.002 asteval.py:72(__init__)
#        89    0.000    0.000    0.000    0.000 asteval.py:89(<genexpr>)
#         2    0.000    0.000    0.000    0.000 asteval.py:94(<genexpr>)
#        38    0.000    0.000    0.000    0.000 asteval.py:98(<genexpr>)
#         4    0.000    0.000    0.000    0.000 astutils.py:179(valid_symbol_name)
#      17/1    0.000    0.000    0.002    0.002 copy.py:137(deepcopy)
#        12    0.000    0.000    0.000    0.000 copy.py:192(_deepcopy_atomic)
#         5    0.000    0.000    0.000    0.000 copy.py:253(_keep_alive)
#         1    0.000    0.000    0.000    0.000 ensemble.py:109(clear_blobs)
#         1    0.000    0.000    0.000    0.000 ensemble.py:116(reset)
#        51    0.006    0.000    9.725    0.191 ensemble.py:130(sample)
#       100    0.011    0.000    9.524    0.095 ensemble.py:292(_propose_stretch)
#       101    0.016    0.000    9.700    0.096 ensemble.py:340(_get_lnprob)
#       101    0.002    0.000    0.002    0.000 ensemble.py:382(<listcomp>)
#       101    0.004    0.000    0.004    0.000 ensemble.py:385(<listcomp>)
#       101    0.001    0.000    0.001    0.000 ensemble.py:386(<listcomp>)
#       101    0.002    0.000    0.002    0.000 ensemble.py:388(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ensemble.py:423(chain)
#         1    0.000    0.000    0.000    0.000 ensemble.py:442(lnprobability)
#         1    0.000    0.000    0.000    0.000 ensemble.py:512(__init__)
#      5100    0.013    0.000    9.672    0.002 ensemble.py:517(__call__)
#         1    0.000    0.000    0.007    0.007 ensemble.py:80(__init__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1206(diagonal)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1686(clip)
#     10201    0.044    0.000    0.156    0.000 fromnumeric.py:1743(sum)
#     10605    0.024    0.000    0.111    0.000 fromnumeric.py:1900(any)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:55(take)
#         2    0.000    0.000    0.000    0.000 function_base.py:1264(copy)
#         1    0.000    0.000    0.000    0.000 function_base.py:2298(cov)
#         1    0.000    0.000    0.000    0.000 function_base.py:2500(corrcoef)
#         1    0.000    0.000    0.001    0.001 function_base.py:3369(_ureduce)
#         1    0.000    0.000    0.001    0.001 function_base.py:3588(percentile)
#         1    0.000    0.000    0.000    0.000 function_base.py:3709(_percentile)
#         1    0.000    0.000    0.000    0.000 function_base.py:857(average)
#      5100    0.161    0.000    9.659    0.002 minimizer.py:1269(_lnpost)
#         1    0.000    0.000    0.000    0.000 minimizer.py:1362(_make_random_gen)
#      5100    0.071    0.000    0.262    0.000 minimizer.py:1380(_nan_policy)
#         1    0.000    0.000    0.000    0.000 minimizer.py:212(__init__)
#         1    0.000    0.000    0.003    0.003 minimizer.py:430(prepare_fit)
#         1    0.000    0.000    0.000    0.000 minimizer.py:474(<dictcomp>)
#         1    0.000    0.000    9.740    9.740 minimizer.py:606(emcee)
#         5    0.000    0.000    0.000    0.000 numeric.py:1404(rollaxis)
#     10200    0.035    0.000    0.087    0.000 numeric.py:2576(seterr)
#     10200    0.032    0.000    0.034    0.000 numeric.py:2676(geterr)
#      5100    0.010    0.000    0.012    0.000 numeric.py:2963(__init__)
#      5100    0.009    0.000    0.060    0.000 numeric.py:2967(__enter__)
#      5100    0.011    0.000    0.048    0.000 numeric.py:2972(__exit__)
#      5155    0.007    0.000    0.023    0.000 numeric.py:414(asarray)
#     10809    0.013    0.000    0.016    0.000 numeric.py:484(asanyarray)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:660(issubclass_)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:728(issubdtype)
#         4    0.000    0.000    0.000    0.000 parameter.py:122(__setitem__)
#      5102    0.036    0.000    0.049    0.000 parameter.py:199(update_constraints)
#      5102    0.011    0.000    0.011    0.000 parameter.py:204(<genexpr>)
#         4    0.000    0.000    0.000    0.000 parameter.py:24(isclose)
#         1    0.000    0.000    0.000    0.000 parameter.py:295(add_many)
#         4    0.000    0.000    0.000    0.000 parameter.py:442(__init__)
#         4    0.000    0.000    0.000    0.000 parameter.py:508(_init_bounds)
#         8    0.000    0.000    0.000    0.000 parameter.py:559(setup_bounds)
#    586631    1.114    0.000    1.967    0.000 parameter.py:613(_getval)
#        16    0.000    0.000    0.000    0.000 parameter.py:653(value)
#    607035    0.576    0.000    0.677    0.000 parameter.py:658(value)
#        12    0.000    0.000    0.000    0.000 parameter.py:669(expr)
#         4    0.000    0.000    0.000    0.000 parameter.py:676(expr)
#         4    0.000    0.000    0.000    0.000 parameter.py:684(__set_expression)
#    204040    0.319    0.000    1.170    0.000 parameter.py:699(__array__)
#         1    0.000    0.000    0.002    0.002 parameter.py:75(__init__)
#    229545    1.619    0.000    2.821    0.000 parameter.py:760(__mul__)
#    153030    0.217    0.000    0.748    0.000 parameter.py:813(__rmul__)
#         1    0.000    0.000    0.002    0.002 parameter.py:91(__deepcopy__)
#         1    0.000    0.000    0.000    0.000 parameter.py:99(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 sampler.py:118(reset)
#         1    0.000    0.000    9.725    9.725 sampler.py:135(run_mcmc)
#         1    0.007    0.007    0.007    0.007 sampler.py:37(__init__)
#        50    0.000    0.000    0.001    0.000 sampler.py:49(random_state)
#         1    0.000    0.000    0.000    0.000 sampler.py:61(random_state)
#         1    0.000    0.000    0.000    0.000 sampler.py:81(chain)
#         1    0.000    0.000    0.000    0.000 sampler.py:97(lnprobability)
#       200    0.001    0.000    0.001    0.000 shape_base.py:61(atleast_2d)
#         1    0.000    0.000    0.000    0.000 twodim_base.py:244(diag)
#         1    0.000    0.000    0.000    0.000 type_check.py:237(iscomplexobj)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#       479    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    9.740    9.740 {built-in method builtins.exec}
#       479    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#    607474    0.102    0.000    0.102    0.000 {built-in method builtins.hasattr}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    596849    0.206    0.000    0.206    0.000 {built-in method builtins.isinstance}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#      1008    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#    225314    0.215    0.000    0.215    0.000 {built-in method numpy.core.multiarray.array}
#     10206    0.057    0.000    0.057    0.000 {built-in method numpy.core.multiarray.concatenate}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.dot}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.result_type}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#     20400    0.006    0.000    0.006    0.000 {built-in method numpy.core.umath.geterrobj}
#     10200    0.014    0.000    0.014    0.000 {built-in method numpy.core.umath.seterrobj}
#         4    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#     10605    0.011    0.000    0.071    0.000 {method 'any' of 'numpy.ndarray' objects}
#     25725    0.014    0.000    0.014    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        35    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        50    0.001    0.000    0.001    0.000 {method 'get_state' of 'mtrand.RandomState' objects}
#      5104    0.003    0.000    0.003    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#      5100    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#       200    0.002    0.000    0.002    0.000 {method 'rand' of 'mtrand.RandomState' objects}
#       100    0.001    0.000    0.001    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'randn' of 'mtrand.RandomState' objects}
#      5101    0.005    0.000    0.005    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     20807    0.133    0.000    0.133    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'set_state' of 'mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#      5100    0.019    0.000    0.055    0.000 {method 'sum' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'collections.OrderedDict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}

# %%
cProfile.run('wym_obj2(parms,ligset,rtots,bindset_n,err)')
# Out:
#          586 function calls in 0.002 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.002    0.002 <ipython-input-54-0d909cedd6b9>:1(wym_obj2)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#       115    0.000    0.000    0.001    0.000 parameter.py:613(_getval)
#       115    0.000    0.000    0.000    0.000 parameter.py:658(value)
#        45    0.000    0.000    0.001    0.000 parameter.py:760(__mul__)
#        70    0.000    0.000    0.000    0.000 parameter.py:813(__rmul__)
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#       115    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       115    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.array}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.concatenate}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
def repr(n):
    for i in range(n):
        wym_obj2(parms,ligset,rtots,bindset_n,err)

# %%
cProfile.run('repr(1000)')
# Out:
#          583004 function calls in 1.013 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1000    0.502    0.001    1.005    0.001 <ipython-input-54-0d909cedd6b9>:1(wym_obj2)
#         1    0.008    0.008    1.013    1.013 <ipython-input-79-c1dd1977d96a>:1(repr)
#         1    0.000    0.000    1.013    1.013 <string>:1(<module>)
#    115000    0.184    0.000    0.329    0.000 parameter.py:613(_getval)
#    115000    0.097    0.000    0.114    0.000 parameter.py:658(value)
#     45000    0.114    0.000    0.295    0.000 parameter.py:760(__mul__)
#     70000    0.043    0.000    0.236    0.000 parameter.py:813(__rmul__)
#         1    0.000    0.000    1.013    1.013 {built-in method builtins.exec}
#    115000    0.017    0.000    0.017    0.000 {built-in method builtins.hasattr}
#    115000    0.031    0.000    0.031    0.000 {built-in method builtins.isinstance}
#      1000    0.005    0.000    0.005    0.000 {built-in method numpy.core.multiarray.array}
#      1000    0.010    0.000    0.010    0.000 {built-in method numpy.core.multiarray.concatenate}
#      5000    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
result.params
# Out:
# Parameters([('k11', <Parameter 'k11', 4.0002713533678866, bounds=[0.01:inf]>),
#             ('k21', <Parameter 'k21', 1.9936230842044997, bounds=[0.01:inf]>),
#             ('k22', <Parameter 'k22', 0.2405232844404892, bounds=[0.01:inf]>),
#             ('l20', <Parameter 'l20', 454.17649544551739, bounds=[0.01:inf]>)])

# %%
result.params['k22'].set(min=0.01,max=1)

# %%
result.params['k22']
# Out:
# <Parameter 'k22', 0.2405232844404892, bounds=[0.01:1]>

# %%
for i in result.params.keys():
    result.params[i].set(min=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-dd22c3ec1388> in <module>()
# ----> 1 for i in result.params.keys:
#       2     print(i)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
result.params['k11'].set(min=0.01,max=10)

# %%
result.params['k21'].set(min=0.01,max=10)

# %%
result.params['l20'].set(min=100,max=550)

# %%
mcmc2 = lmfit.Minimizer(lnprob2, result.params, fcn_args=(ligset,rtots,bindset_n,err))

# %%
result2_mc = mcmc2.emcee(steps=1000)

# %%
result2_mc.params
# Out:
# Parameters([('k11',
#              <Parameter 'k11', value=4.2606389959072457 +/- 0.00069, bounds=[0.01:10]>),
#             ('k21',
#              <Parameter 'k21', value=1.9233884926576719 +/- 3.25e-05, bounds=[0.01:10]>),
#             ('k22',
#              <Parameter 'k22', value=0.99999663445384546 +/- 0.0542, bounds=[0.01:1]>),
#             ('l20',
#              <Parameter 'l20', value=549.99991822321738 +/- 0.553, bounds=[100:550]>)])

# %%
sim_parms
# Out:
# {'k11': 3.75, 'k21': 1.81, 'k22': 0.115, 'l20': 283.0}

# %%
corner.corner(result2_mc.flatchain)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
