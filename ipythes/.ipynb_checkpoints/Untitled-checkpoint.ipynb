# %%
import numpy as np

# %%
a = np.genfromtxt('All_WT_for_coopfit_tsv.csv',delimiter='\t')

# %%
a
# Out:
# array([[             nan,              nan,              nan, ...,
#                      nan,              nan,              nan],
#        [  7.96945700e-03,   4.60385500e-02,              nan, ...,
#                      nan,              nan,              nan],
#        [  1.49932600e-02,   7.30192700e-02,              nan, ...,
#                      nan,              nan,              nan],
#        ...,
#        [  5.55989800e+00,              nan,              nan, ...,
#                      nan,              nan,   8.32284500e-01],
#        [  7.70544500e+00,              nan,              nan, ...,
#                      nan,              nan,   8.74716000e-01],
#        [  1.22711300e+01,              nan,              nan, ...,
#                      nan,              nan,   8.67848800e-01]])

# %%
import csv

# %%
f = open('All_WT_for_coopfit_tsv.csv')

# %%
a = list(csv.reader(f, delimiter='\t'))

# %%
a
# Out:
# [['[egf]',
#   '24k',
#   '43k',
#   '92k',
#   '120k',
#   '231k',
#   '447k',
#   '20K',
#   '46K',
#   '187K',
#   '256K',
#   '1200K',
#   '12k',
#   '82k',
#   '107k',
#   '387k',
#   '502k',
#   '1600k'],
#  ['0.007969457',
#   '0.04603855',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['0.01499326',
#   '0.07301927',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['0.03099519',
#   '0.1115632',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['0.06109528',
#   '0.1925054',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['0.09514861',
#   '0.2426124',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
# ...

# %%
len(a)
# Out:
# 240

# %%
b = a[1:240]

# %%
len(b[1])
# Out:
# 18

# %%
c = []
temp = []
for i in range(len(b)):
    for j in range(0,18):
        if b[i][j] != '':
            temp.append(b[i][j])
            c.append(temp)
    temp = []

# %%
c
# Out:
# [['0.007969457'],
#  ['0.04603855'],
#  ['0.01499326'],
#  ['0.07301927'],
#  ['0.03099519'],
#  ['0.1115632'],
#  ['0.06109528'],
#  ['0.1925054'],
#  ['0.09514861'],
#  ['0.2426124'],
#  ['0.1439648'],
#  ['0.3466809'],
#  ['0.243969'],
#  ['0.4411135'],
#  ['0.3945051'],
#  ['0.5066381'],
#  ['0.686923'],
#  ['0.7147752'],
#  ['1.079399'],
#  ['0.8130621'],
#  ['1.847583'],
#  ['0.8535332'],
#  ['2.618645'],
#  ['0.8901499'],
#  ['4.197115'],
#  ['0.8997859'],
#  ['8.121298'],
#  ['0.9460385'],
#  ['16.013240'],
#  ['0.9961456'],
#  ['0.008435078'],
#  ['0.03062099'],
#  ['0.01632461'],
#  ['0.05952891'],
#  ['0.03219274'],
#  ['0.09614561'],
#  ['0.06589953'],
#  ['0.1732334'],
#  ['0.09789267'],
#  ['0.2310493'],
#  ['0.1495181'],
#  ['0.337045'],
#  ['0.2533132'],
#  ['0.4565311'],
#  ['0.3979881'],
#  ['0.5683084'],
#  ['0.6938425'],
#  ['0.6588865'],
#  ['1.831155'],
#  ['0.8053533'],
#  ['2.570049'],
#  ['0.8766595'],
#  ['5.068029'],
#  ['0.9171307'],
#  ['8.196809'],
# ...

# %%
c.a[[en]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-576ba2bd51f5> in <module>()
# ----> 1 c[1] = 2
#
# IndexError: list assignment index out of range
