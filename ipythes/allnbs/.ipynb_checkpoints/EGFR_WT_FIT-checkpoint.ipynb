# %%
import numpy as np
import matplotlib.pyplot as plt
import models
import corner
from scipy import optimize
from Pymod import prep
from plotter import semlog
# %matplotlib inline
# %load_ext autoreload

# %%
WT_08_lbl, WT_08_rtot, WT_08_lig, WT_08_sat = prep.datprep('Data/EGFR_WT_08_Sat.csv','Data/EGFR_WT_08_Rtot.csv')
# Out:
# hootie hoo! the indices match!

# %%
WT_09_lbl, WT_09_rtot, WT_09_lig, WT_09_sat = prep.datprep('Data/EGFR_WT_09_Sat.csv','Data/EGFR_WT_09_Rtot.csv')
# Out:
# hootie hoo! the indices match!

# %%
WT_11_lbl, WT_11_rtot, WT_11_lig, WT_11_sat = prep.datprep('Data/EGFR_WT_11_Sat.csv','Data/EGFR_WT_11_Rtot.csv')
# Out:
# hootie hoo! the indices match!

# %%
all_rtots = np.concatenate([WT_08_rtot,WT_09_rtot,WT_11_rtot])

# %%
all_ligs = np.concatenate([WT_08_lig,WT_09_lig,WT_11_lig])

# %%
all_sats = np.concatenate([WT_08_sat,WT_09_sat,WT_11_sat])

# %%
all_labs = np.concatenate([WT_08_lbl,WT_09_lbl,WT_11_lbl])

# %%
semlog(all_ligs,all_sats,all_labs)

# %%
predicted = np.array([
5.70E-04,
1.02E-03,
2.18E-03,
2.85E-03,
5.48E-03,
1.06E-02,
4.75E-04,
1.09E-03,
4.44E-03,
6.07E-03,
2.85E-02,
2.85E-04,
1.95E-03,
2.54E-03,
9.18E-03,
1.19E-02,
3.80E-02])

# %%
plt.plot(predicted,all_rtots,'.')

# %%
guess = np.array([4.6,5.3,0.34,530.])

# %%
bounds1 = ((0.,0.,0.,0.),(10.,10.,10.,10000.))

# %%
res2 = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(all_ligs,all_sats,all_rtots))

# %%
res2.x
# Out:
# array([  3.74744078e+00,   1.81369998e+00,   1.15548972e-01,
#          2.83401420e+02])

# %%
for i in range(len(all_ligs)):
    plt.semilogx(all_ligs[i], models.wyman_bestfit(res2.x,all_ligs[i],all_rtots[i]),'-',color="black")
    plt.semilogx(all_ligs[i], all_sats[i],'.')

# %%
errs = all_sats*0.05

# %%
res3 = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(all_ligs,all_sats,all_rtots,errs))

# %%
res3.x
# Out:
# array([  3.69121730e+00,   7.11229840e-01,   1.63837540e-02,
#          2.11579143e+02])

# %%
for i in range(len(all_ligs)):
    plt.semilogx(all_ligs[i], models.wyman_bestfit(res3.x,all_ligs[i],all_rtots[i]),'-',color="black")
    plt.semilogx(all_ligs[i], all_sats[i],'.')

# %%
res4 = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(all_ligs,all_sats,all_rtots,),loss='soft_l1')

# %%
res4.x
# Out:
# array([  3.74779499e+00,   1.81246460e+00,   1.15650823e-01,
#          2.83586103e+02])

# %%
res2.x
# Out:
# array([  3.74744078e+00,   1.81369998e+00,   1.15548972e-01,
#          2.83401420e+02])

# %%
res5 = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(all_ligs,all_sats,all_rtots,errs),loss='soft_l1')

#         -3.30392221e-03,   4.16823515e-02,   5.33530812e-02,
#          5.35682573e-02,   1.11769513e-02,   5.88646795e-02,
#          3.12405957e-02,   3.44311692e-02,   2.32769640e-02,
#          5.77659219e-02,   3.87497791e-03,   5.87296061e-03,
#          1.90413052e-02,   1.77359331e-02,   2.26797766e-02,
#          1.93768500e-02,   1.52550368e-02,   9.36411755e-03,
#          2.77403502e-04,  -3.48285439e-03,   1.14012142e-02,
#          9.77350254e-02,   8.14166717e-03,  -4.18673741e-02,
#         -1.94291998e-02,  -3.13366430e-02,  -1.02895600e-02,
#         -3.99613844e-02,   2.42110437e-02,   2.47561436e-02,
#          4.24708518e-02,   5.24538672e-02,   3.93973224e-02,
#         -1.96821575e-02,  -9.27558005e-03,  -2.73791240e-02,
#          4.33329959e-02,   2.98097731e-02,   3.48346211e-02,
#          1.03050576e-02,   7.90077823e-03,   1.30666172e-02,
#          3.23891452e-02,   3.73650419e-02,   4.79449903e-02,
#          1.84226327e-02,  -6.78390689e-02,  -4.85662324e-03,
#          8.24716182e-03,  -5.35827029e-02,   4.84796482e-02,
#          2.54128855e-02,  -1.11103447e-02,   6.07452016e-03,
#          1.12002956e-02,   1.68576789e-02,   2.12589367e-02,
#          3.30809850e-02,   4.65039476e-02,   2.93235359e-02,
#         -3.20101456e-03,   2.34081021e-02,  -8.92135476e-02,
#         -4.50389305e-02,  -4.01430607e-02,  -4.62963554e-03,
#         -5.23684972e-03,   8.69072105e-03,   1.51045838e-02,
#          1.92535486e-02,   1.96416323e-02,   2.35941571e-02,
#          2.15514243e-02,   3.65359086e-02,   2.77342247e-02,
#         -4.84179551e-04,  -2.75709244e-02,  -7.65418506e-02,
#          2.59777348e-02,  -3.68540262e-02,   4.89158588e-02,
#          3.17326901e-03,   9.21849439e-03,   1.21210187e-02,
#          1.51701245e-02,   2.71768851e-02,   3.60753660e-02,
#          3.50003763e-02,   3.90659117e-03,   1.09742760e-02,
#         -4.06985607e-02,  -7.41040198e-03,  -5.90601967e-03,
#         -1.61969748e-02,   4.60010968e-02,  -2.12074447e-03,
#          8.77052269e-03,   2.08340749e-02,   2.65778065e-02,
#          3.80798951e-02,   5.59434428e-02,   5.70818277e-02,
#          5.20319056e-02,   4.60663726e-02,   2.08284440e-02,
#         -3.85246270e-02,  -4.38131530e-02,  -2.54561783e-02,
#         -2.77101088e-02,   2.54445844e-02])

# %%
for i in all_ligs:
    print(i.size)
# Out:
# 15
# 13
# 13
# 13
# 12
# 15
# 14
# 15
# 15
# 14
# 14
# 15
# 13
# 14
# 15
# 14
# 15

# %%
resl = res5.fun

# %%
expected = models.wyman_bestfit(res3.x,all_ligs[0],all_rtots[0])
resl3 = res3.fun[0:15]

# %%
plt.plot(resl3,'.')

# %%
newsl = resl3/expected

# %%
plt.plot(newsl)

# %%
res2.cost
# Out:
# 0.15561055883542796

# %%
res2.fun
# Out:
# array([ -2.44707093e-02,  -3.31365678e-02,  -3.22163135e-02,
#         -4.65018168e-02,  -3.12542433e-02,  -5.64598547e-02,
# array([   3.79528235,    5.44194489,    0.19624525,  170.09725774])

# %%
res2.x
# Out:
# array([  3.74744078e+00,   1.81369998e+00,   1.15548972e-01,
#          2.83401420e+02])

# %%
plt.plot(res_wt1.fun,'.')

# %%
WT_08_err = 0.05*WT_08_sat

# %%
res_wt1h = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(WT_08_lig,WT_08_sat,WT_08_rtot,WT_08_err))

# %%
res_wt1h.x
# Out:
# array([  6.24977378e+00,   6.00343234e+00,   4.96988963e-01,
#          3.48860743e+03])

# %%
plt.plot(res_wt1h.fun,'.')

# %%
from scipy import stats

# %%
stats.normaltest(res_wt1.fun)
# Out:
# NormaltestResult(statistic=1.6828038729929593, pvalue=0.43110571673971432)

# %%
stats.normaltest(res_wt1h.fun)
# Out:
# NormaltestResult(statistic=21.791069692999375, pvalue=1.8540837124498822e-05)

# %%
stats.shapiro(res_wt1.fun)
# Out:
# (0.9917553067207336, 0.8898860216140747)

# %%
stats.shapiro(res_wt1h.fun)
# Out:
# (0.8277326822280884, 2.6864293900530356e-08)

# %%
np.mean(res_wt1.fun)
# Out:
# -0.00053258661972699285

# %%
np.mean(res_wt1h.fun)
# Out:
# -0.22333777560642967

# %%
colors = ['b','g','r','c','m','y','k']

# %%
for i in range(len(WT_08_lig)):
    plt.semilogx(WT_08_lig[i], models.wyman_bestfit(res_wt1.x,WT_08_lig[i],WT_08_rtot[i]),'-',color=colors[i])
    plt.semilogx(WT_08_lig[i], WT_08_sat[i],'.',color=colors[i])

# %%
WT_08_lig
# Out:
# array([ array([  7.96945700e-03,   1.49932600e-02,   3.09951900e-02,
#          6.10952800e-02,   9.51486100e-02,   1.43964800e-01,
#          2.43969000e-01,   3.94505100e-01,   6.86923000e-01,
#          1.07939900e+00,   1.84758300e+00,   2.61864500e+00,
#          4.19711500e+00,   8.12129800e+00,   1.60132400e+01]),
#        array([ 0.00843508,  0.01632461,  0.03219274,  0.06589953,  0.09789267,
#         0.1495181 ,  0.2533132 ,  0.3979881 ,  0.6938425 ,  1.831155  ,
#         2.570049  ,  5.068029  ,  8.196809  ]),
#        array([  1.04782800e-02,   4.39510000e-02,   6.71754600e-02,
#          1.59764000e-01,   2.75784200e-01,   4.67317900e-01,
#          8.37884700e-01,   1.34129100e+00,   2.29507100e+00,
#          3.22207200e+00,   5.06843800e+00,   9.99232400e+00,
#          1.63226300e+01]),
#        array([  0.02105896,   0.04394744,   0.06716596,   0.142679  ,
#          0.237226  ,   0.3870431 ,   0.4670442 ,   1.080119  ,
#          1.830193  ,   2.595465  ,   4.079464  ,   8.197306  ,  16.17389   ]),
#        array([ 0.02985244,  0.06170198,  0.09792828,  0.142702  ,  0.244107  ,
#         0.3909656 ,  0.7009451 ,  1.090977  ,  1.849451  ,  2.621134  ,
#         5.115771  ,  8.046807  ]),
#        array([  7.67501400e-03,   1.49975000e-02,   2.95726500e-02,
#          6.11212100e-02,   9.69908500e-02,   1.44087100e-01,
#          2.48778100e-01,   3.94624700e-01,   6.87951000e-01,
#          1.17700400e+00,   1.83259900e+00,   2.57264700e+00,
#          4.08259800e+00,   8.05087400e+00,   1.60190700e+01])], dtype=object)

# %%
WT_08_sat
# Out:
# array([ array([ 0.04603855,  0.07301927,  0.1115632 ,  0.1925054 ,  0.2426124 ,
#         0.3466809 ,  0.4411135 ,  0.5066381 ,  0.7147752 ,  0.8130621 ,
#         0.8535332 ,  0.8901499 ,  0.8997859 ,  0.9460385 ,  0.9961456 ]),
#        array([ 0.03062099,  0.05952891,  0.09614561,  0.1732334 ,  0.2310493 ,
#         0.337045  ,  0.4565311 ,  0.5683084 ,  0.6588865 ,  0.8053533 ,
#         0.8766595 ,  0.9171307 ,  0.9633833 ]),
#        array([ 0.04411135,  0.1038544 ,  0.1443255 ,  0.3158458 ,  0.4507495 ,
#         0.5528908 ,  0.6685225 ,  0.7957174 ,  0.8689507 ,  0.9132763 ,
#         0.9094219 ,  0.9730192 ,  0.9710921 ]),
#        array([ 0.07301927,  0.1115632 ,  0.1578158 ,  0.3023555 ,  0.4141328 ,
#         0.5278373 ,  0.6087794 ,  0.7494647 ,  0.8554604 ,  0.8381156 ,
#         0.9113491 ,  0.9576017 ,  0.9441114 ]),
#        array([ 0.09421842,  0.1501071 ,  0.1963597 ,  0.2869379 ,  0.3871521 ,
#         0.466167  ,  0.5875803 ,  0.6955032 ,  0.7571734 ,  0.7995718 ,
#         0.9229122 ,  0.9248394 ]),
#        array([ 0.03640257,  0.04603855,  0.09229122,  0.1520343 ,  0.2137045 ,
#         0.2657388 ,  0.3794433 ,  0.4777302 ,  0.5721628 ,  0.6569593 ,
#         0.7301927 ,  0.7802998 ,  0.8381156 ,  0.8766595 ,  0.9614561 ])], dtype=object)

# %%
temp = np.concatenate(WT_08_sat)

# %%
type(temp)
# Out:
# numpy.ndarray

# %%
np.savetxt('derpsat',temp)

# %%
WT_08_rtot
# Out:
# array([ 0.001439,  0.002422,  0.003392,  0.002718,  0.01216 ,  0.02594 ])

# %%
i = 2
plt.semilogx(WT_08_lig[i], models.wyman_bestfit(res_wt1.x,WT_08_lig[i],WT_08_rtot[i]),'-',color=colors[i])
plt.semilogx(WT_08_lig[i], models.wyman_bestfit(res_wt1h.x,WT_08_lig[i],WT_08_rtot[i]),'--',color=colors[i])
plt.semilogx(WT_08_lig[i], WT_08_sat[i],'.',color=colors[i])

# %%
res_wt1.x
# Out:
# array([   3.79528235,    5.44194489,    0.19624525,  170.09725774])

# %%
res_wt1h.x
# Out:
# array([  6.24977378e+00,   6.00343234e+00,   4.96988963e-01,
#          3.48860743e+03])

# %%
res_wt09 = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(WT_09_lig,WT_09_sat,WT_09_rtot))

# %%
res_wt09.x
# Out:
# array([  4.49640468e+00,   1.92956694e+00,   2.02804163e-01,
#          1.08210252e+03])

# %%
WT_09_err = 0.05*WT_09_sat

# %%
res_wt09h = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(WT_09_lig,WT_09_sat,WT_09_rtot,WT_09_err))

# %%
res_wt09h.x
# Out:
# array([  3.96106789e+00,   1.26915879e+00,   4.70044433e-01,
#          8.30822483e+02])

# %%
# %autoreload

# %%
models.viewf(res_wt09.x,WT_09_lig,WT_09_sat,WT_09_rtot)
models.viewf(res_wt09h.x,WT_09_lig,WT_09_sat,WT_09_rtot,symbol='--')

# %%
plt.plot(res_wt09.fun[0:14],'.')
plt.plot(res_wt09h.fun[0:14],'.',color='r')

# %%
res_wt09.fun.mean()
# Out:
# -0.0027295798169837248

# %%
WT_09_lig[0].size
# Out:
# 14

# %%
stats.shapiro(res_wt09h.fun[0:14])
# Out:
# (0.8500391244888306, 0.02223745733499527)

# %%
res_wt09l = optimize.least_squares(models.wyman_sp,guess,loss='pew', bounds=bounds1,args=(WT_09_lig,WT_09_sat,WT_09_rtot))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-8027a9eaa6a3> in <module>()
# ----> 1 res_wt09l = optimize.least_squares(models.wyman_sp,guess,loss='pew', bounds=bounds1,args=(WT_09_lig,WT_09_sat,WT_09_rtot))
#
# /Users/michael/miniconda3/envs/fitter/lib/python3.5/site-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     723     if loss not in IMPLEMENTED_LOSSES and not callable(loss):
#     724         raise ValueError("`loss` must be one of {0} or a callable."
# --> 725                          .format(IMPLEMENTED_LOSSES.keys()))
#     726
#     727     if method == 'lm' and loss != 'linear':
#
# ValueError: `loss` must be one of dict_keys(['huber', 'soft_l1', 'cauchy', 'arctan', 'linear']) or a callable.

# %%
res_wt09.x
# Out:
# array([  4.49640468e+00,   1.92956694e+00,   2.02804163e-01,
#          1.08210252e+03])

# %%
plt.plot(res_wt09l.fun)

# %%
res_wt11 = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(WT_11_lig,WT_11_sat,WT_11_rtot))

# %%
WT_11_err = 0.05*WT_11_sat

# %%
res_wt11.x
# Out:
# array([  3.35242893e+00,   9.08239773e-01,   1.69319709e-01,
#          2.25990844e+02])

# %%
res_wt11h = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(WT_11_lig,WT_11_sat,WT_11_rtot,WT_11_err))

# %%
res_wt11h.x
# Out:
# array([  3.63854196e+00,   6.34825961e-01,   7.11031603e-02,
#          2.23403530e+02])

# %%
models.viewf(res_wt11.x,WT_11_lig,WT_11_sat,WT_11_rtot)
models.viewf(res_wt11h.x,WT_11_lig,WT_11_sat,WT_11_rtot,symbol='--')

# %%
sepfits = np.stack([res_wt1.x,res_wt09.x,res_wt11.x],axis=0)

# %%
np.mean(sepfits,axis=0)
# Out:
# array([  3.88137199e+00,   2.75991720e+00,   1.89456373e-01,
#          4.92730207e+02])

# %%
sepfits
# Out:
# array([[  3.79528235e+00,   5.44194489e+00,   1.96245247e-01,
#           1.70097258e+02],
#        [  4.49640468e+00,   1.92956694e+00,   2.02804163e-01,
#           1.08210252e+03],
#        [  3.35242893e+00,   9.08239773e-01,   1.69319709e-01,
#           2.25990844e+02]])

# %%
res2.x
# Out:
# array([  3.74744078e+00,   1.81369998e+00,   1.15548972e-01,
#          2.83401420e+02])

# %%
plt.plot(res_wt09h.fun,'.')

# %%
res_all = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(all_ligs,all_sats,all_rtots))

# %%
res_all.x
# Out:
# array([  3.74744078e+00,   1.81369998e+00,   1.15548972e-01,
#          2.83401420e+02])

# %%
plt.plot(res_all.fun)

# %%
stats.shapiro(res_all.fun)
# Out:
# (0.9863876104354858, 0.02242036536335945)

# %%
res_allr = optimize.least_squares(models.wyman_sp,guess,loss='soft_l1',bounds=bounds1,args=(all_ligs,all_sats,all_rtots))

# %%
all_errs = all_sats*0.05

# %%
res_allh = optimize.least_squares(models.wyman_sp,guess,bounds=bounds1,args=(all_ligs,all_sats,all_rtots,all_errs))

# %%
res_allh.x
# Out:
# array([  3.69121730e+00,   7.11229840e-01,   1.63837540e-02,
#          2.11579143e+02])

# %%
# %autoreload

# %%
models.viewf(res_all.x,all_ligs,all_sats,all_rtots)
models.viewf(res_allr.x,all_ligs,all_sats,all_rtots,symbol='--')

# %%
all_ligs
# Out:
# array([ array([  7.96945700e-03,   1.49932600e-02,   3.09951900e-02,
#          6.10952800e-02,   9.51486100e-02,   1.43964800e-01,
#          2.43969000e-01,   3.94505100e-01,   6.86923000e-01,
#          1.07939900e+00,   1.84758300e+00,   2.61864500e+00,
#          4.19711500e+00,   8.12129800e+00,   1.60132400e+01]),
#        array([ 0.00843508,  0.01632461,  0.03219274,  0.06589953,  0.09789267,
#         0.1495181 ,  0.2533132 ,  0.3979881 ,  0.6938425 ,  1.831155  ,
#         2.570049  ,  5.068029  ,  8.196809  ]),
#        array([  1.04782800e-02,   4.39510000e-02,   6.71754600e-02,
#          1.59764000e-01,   2.75784200e-01,   4.67317900e-01,
#          8.37884700e-01,   1.34129100e+00,   2.29507100e+00,
#          3.22207200e+00,   5.06843800e+00,   9.99232400e+00,
#          1.63226300e+01]),
#        array([  0.02105896,   0.04394744,   0.06716596,   0.142679  ,
#          0.237226  ,   0.3870431 ,   0.4670442 ,   1.080119  ,
#          1.830193  ,   2.595465  ,   4.079464  ,   8.197306  ,  16.17389   ]),
#        array([ 0.02985244,  0.06170198,  0.09792828,  0.142702  ,  0.244107  ,
#         0.3909656 ,  0.7009451 ,  1.090977  ,  1.849451  ,  2.621134  ,
#         5.115771  ,  8.046807  ]),
#        array([  7.67501400e-03,   1.49975000e-02,   2.95726500e-02,
#          6.11212100e-02,   9.69908500e-02,   1.44087100e-01,
#          2.48778100e-01,   3.94624700e-01,   6.87951000e-01,
#          1.17700400e+00,   1.83259900e+00,   2.57264700e+00,
#          4.08259800e+00,   8.05087400e+00,   1.60190700e+01]),
#        array([  0.01713749,   0.03444448,   0.07655431,   0.1450889 ,
#          0.251269  ,   0.4142728 ,   0.7255647 ,   1.060153  ,
#          1.819164  ,   2.552526  ,   4.121284  ,   6.136859  ,
#          8.368795  ,  12.34485   ]),
#        array([  1.03056800e-02,   1.97048800e-02,   3.96082700e-02,
#          8.04407000e-02,   1.19932100e-01,   1.58630700e-01,
#          2.53687600e-01,   4.05729100e-01,   7.24835200e-01,
#          1.04858300e+00,   1.79791200e+00,   2.60332900e+00,
#          4.11789300e+00,   8.36305800e+00,   1.24656700e+01]),
#        array([  1.04079700e-02,   2.19853700e-02,   2.42903700e-02,
#          8.12168300e-02,   1.19871800e-01,   1.60153900e-01,
#          2.50999200e-01,   4.05474000e-01,   7.38315600e-01,
#          1.02750900e+00,   1.79844600e+00,   2.55025100e+00,
#          4.11610500e+00,   8.27783800e+00,   1.25876700e+01]),
#        array([  0.01836968,   0.02878571,   0.06082663,   0.1152153 ,
#          0.2055712 ,   0.3524264 ,   0.6354886 ,   0.9669508 ,
#          1.675933  ,   2.44816   ,   4.034029  ,   6.195363  ,
#          8.192737  ,  12.45058   ]),
#        array([  1.29597000e-02,   2.79261500e-02,   5.66855900e-02,
#          8.79264600e-02,   1.31057000e-01,   2.22472800e-01,
#          3.62950200e-01,   6.54465000e-01,   1.00584700e+00,
#          1.76008800e+00,   2.52132200e+00,   4.06792600e+00,
#          8.35426700e+00,   1.61477500e+01]),
#        array([  0.01631733,   0.033773  ,   0.0684047 ,   0.08990054,
#          0.1651807 ,   0.2820976 ,   0.4317393 ,   0.7783454 ,
#          1.068384  ,   1.80568   ,   2.669588  ,   4.307405  ,
#          6.418342  ,   8.512644  ,  12.84846   ]),
#        array([  0.01611945,   0.0352023 ,   0.07328256,   0.1430707 ,
#          0.2428421 ,   0.3778524 ,   0.7089943 ,   1.036456  ,
#          1.893233  ,   4.393878  ,   6.403579  ,   8.504394  ,  14.24382   ]),
#        array([  1.12189300e-02,   1.87615200e-02,   3.57656700e-02,
#          6.71343700e-02,   1.26858200e-01,   2.26001300e-01,
#          3.69250700e-01,   6.66551200e-01,   1.01053200e+00,
#          1.77975300e+00,   2.58740400e+00,   6.36463400e+00,
#          8.48311900e+00,   1.26542500e+01]),
#        array([  0.01298098,   0.03155812,   0.05824695,   0.07851144,
#          0.1483385 ,   0.2435003 ,   0.4066816 ,   0.713275  ,
#          0.9846593 ,   1.766929  ,   2.575723  ,   4.142375  ,
#          6.479044  ,   8.427099  ,  12.68855   ]),
#        array([  1.13943300e-02,   2.32919300e-02,   5.03018300e-02,
#          9.86225200e-02,   1.75471700e-01,   2.97585600e-01,
#          5.57369200e-01,   8.26670500e-01,   1.52277200e+00,
#          2.28366100e+00,   3.91000300e+00,   6.10621300e+00,
#          9.17992300e+00,   1.41383400e+01]),
#        array([  1.02255100e-02,   1.71930400e-02,   3.69002200e-02,
#          5.10800100e-02,   9.63540600e-02,   1.71324800e-01,
#          2.79624100e-01,   4.92992600e-01,   6.72909500e-01,
#          1.36133200e+00,   1.96587600e+00,   3.56075600e+00,
#          5.55989800e+00,   7.70544500e+00,   1.22711300e+01])], dtype=object)

# %%
all_ligs[16]
# Out:
# array([  1.02255100e-02,   1.71930400e-02,   3.69002200e-02,
#          5.10800100e-02,   9.63540600e-02,   1.71324800e-01,
#          2.79624100e-01,   4.92992600e-01,   6.72909500e-01,
#          1.36133200e+00,   1.96587600e+00,   3.56075600e+00,
#          5.55989800e+00,   7.70544500e+00,   1.22711300e+01])
